# %% [markdown]
# # My First Notebook

# %% [markdown]
# ## Read in the list of contributors and committees

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
props.prop_name.unique
# Out:
# <bound method Series.unique of 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.reset_index()
# Out:
#      index                                          prop_name
# 0        0  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1        1  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2        2  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3        3  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4        4  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5        5  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6        6  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7        7  PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8        8  PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9        9  PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10      10  PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11      11  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12      12  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13      13  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# ...

# %%
props.prop_name.unique()
# Out:
# array([ 'PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-12 SCHOOL AND COMMUNITY COLLEGE FACILITIES. INITIATIVE STATUTORY AMENDMENT.',
#        'PROPOSITION 052 - STATE FEES ON HOSPITALS. FEDERAL MEDI-CAL MATCHING FUNDS. INITIATIVE STATUTORY AND CONSTITUTIONAL AMENDMENT.',
#        'PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOTER APPROVAL. INITIATIVE CONSTITUTIONAL AMENDMENT.',
#        'PROPOSITION 054 - LEGISLATURE. LEGISLATION AND PROCEEDINGS. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.',
#        'PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.',
#        'PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.',
#        'PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.',
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name == 'PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86      True
# 87      True
# 88      True
# 89      True
# 90      True
# 91      True
# 92      True
# 93      True
# 94      True
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: prop_name, Length: 102, dtype: bool

# %%
props[props.prop_name == 'PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 86  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 87  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 88  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 89  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 90  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 91  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 92  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 93  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 94  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#     ccdc_prop_id                                          prop_name  \
# 86            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 87            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.']

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33828 entries, 0 to 33827
# Data columns (total 20 columns):
# ocd_prop_id                     33828 non-null object
# calaccess_prop_id               33828 non-null int64
# ccdc_prop_id                    33828 non-null int64
# prop_name                       33828 non-null object
# ccdc_committee_id               33828 non-null int64
# calaccess_committee_id          33828 non-null int64
# committee_name_x                33828 non-null object
# committee_position              33828 non-null object
# committee_name_y                33828 non-null object
# calaccess_filing_id             33828 non-null int64
# date_received                   33828 non-null object
# contributor_lastname            33824 non-null object
# contributor_firstname           33288 non-null object
# contributor_city                33825 non-null object
# contributor_state               33824 non-null object
# ...

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 1  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 2  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 3  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 4  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#    ccdc_prop_id                                          prop_name  \
# 0            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 1            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 2            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 3            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 4            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                468                 1346266
# ...

# %% [markdown]
# merged.amount

# %%
merged.amount.sum()
# Out:
# 34291239.299999997

# %%
merged.amount.sum()
# Out:
# 34291239.299999997

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %% [markdown]
# support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29633 entries, 0 to 33758
# Data columns (total 20 columns):
# ocd_prop_id                     29633 non-null object
# calaccess_prop_id               29633 non-null int64
# ccdc_prop_id                    29633 non-null int64
# prop_name                       29633 non-null object
# ccdc_committee_id               29633 non-null int64
# calaccess_committee_id          29633 non-null int64
# committee_name_x                29633 non-null object
# committee_position              29633 non-null object
# committee_name_y                29633 non-null object
# calaccess_filing_id             29633 non-null int64
# date_received                   29633 non-null object
# contributor_lastname            29633 non-null object
# contributor_firstname           29160 non-null object
# contributor_city                29633 non-null object
# contributor_state               29633 non-null object
# ...

# %%
support.amount.sum()
# Out:
# 16836069.809999999

# %%
oppose.amount.sum()
# Out:
# 17455169.490000002

# %%
support.amount.sum()/merged.amount.sum()
# Out:
# 0.49097291768046425

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
merged
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 0      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 1      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 2      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 3      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 4      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 5      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 6      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 7      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 8      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 9      ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 10     ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# ...

# %%
oppose.sort_values("amount", ascending = False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 29634  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 33752  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29635  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29633  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29631  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29636  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32559  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 30799  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32774  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29934  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32841  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#                                     committee_name_x        amount
# 1  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...  8.387852e+06
# 0  CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...  8.343218e+06
# 7  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...  7.621678e+06
# 2       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  6.140000e+06
# 3  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...  2.110000e+06
# 4  NO ON PROP 66, CALIFORNIANS FOR FAIR JUSTICE, ...  1.486701e+06
# 6  SAN FRANCISCO POLICE OFFICERS ASSOCIATION ISSU...  1.050000e+05
# 5  PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...  9.679012e+04

# %% [markdown]
# merged.groupby("contributor_lastname, contributor_firstname"

# %%
merged.groupby(["contributor_lastname", "contributor_firstname", "committee_position", "committee_name_x", "contributor_occupation", "contributor_employer"]).amount.sum().reset_index().sort_values ("amount", ascending = False)
# Out:
#       contributor_lastname contributor_firstname committee_position  \
# 26022               STEYER                THOMAS             OPPOSE
# 17402              MCKEOWN              NICHOLAS             OPPOSE
# 11695             HASTINGS                  REED             OPPOSE
# 10640               GRAHAM                  PAUL             OPPOSE
# 7212                 DOERR               L. JOHN             OPPOSE
# 19421         NICHOLAS III              HENRY T.            SUPPORT
# 8155               EUSTACE           ROBERT ALAN             OPPOSE
# 10884                GROFF                 SUSAN            SUPPORT
# 2722         BOECKMANN, II                 H. F.            SUPPORT
# 20765            PERENCHIO            A. JERROLD            SUPPORT
# 25947           STEINHARDT            DEBRA JANE            SUPPORT
# 21607            QUATTRONE                 FRANK             OPPOSE
# 6703               DELANEY               M QUINN             OPPOSE
# ...

# %%
merged.amount.sum()
# Out:
# 34291239.299999997

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    29633
# OPPOSE      4195
# Name: committee_position, dtype: int64

# %%
merged.sort_values("amount", ascending = False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 29634  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 33752  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29635  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29633  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29631  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32841  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32774  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32559  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 30799  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29636  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29934  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# ...

# %% [markdown]
# ## Sort to see top contributors to campaigns for or against Prop. 66

# %%
oppose.sort_values("amount", ascending = False).head(10)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 29634  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 33752  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29635  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29633  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29631  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29636  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32559  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 30799  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 32774  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29934  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#        ccdc_prop_id                                          prop_name  \
# ...

# %% [markdown]
# ## Sort to see which Prop 66 committees received the most total contributions

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#                                     committee_name_x        amount
# 1  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...  8.387852e+06
# 0  CALIFORNIA CORRECTIONAL PEACE OFFICERS ASSOCIA...  8.343218e+06
# 7  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...  7.621678e+06
# 2       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  6.140000e+06
# 3  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...  2.110000e+06
# 4  NO ON PROP 66, CALIFORNIANS FOR FAIR JUSTICE, ...  1.486701e+06
# 6  SAN FRANCISCO POLICE OFFICERS ASSOCIATION ISSU...  1.050000e+05
# 5  PROTEUS ACTION LEAGUE NON-PROFIT 501 (C)(4) OR...  9.679012e+04

# %% [markdown]
# ## Sort to see top contributors and their positions

# %%
merged.groupby(["contributor_lastname", "contributor_firstname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#       contributor_lastname contributor_firstname committee_position     amount
# 26001               STEYER                THOMAS             OPPOSE  1750000.0
# 17392              MCKEOWN              NICHOLAS             OPPOSE  1500000.0
# 11693             HASTINGS                  REED             OPPOSE  1000000.0
# 10634               GRAHAM                  PAUL             OPPOSE   500000.0
# 7208                 DOERR               L. JOHN             OPPOSE   500000.0
# 19414         NICHOLAS III              HENRY T.            SUPPORT   400000.0
# 18832             MOTAMEDI                 JULIE            SUPPORT   350000.0
# 8147               EUSTACE           ROBERT ALAN             OPPOSE   175000.0
# 10880                GROFF                 SUSAN            SUPPORT   160000.0
# 8761              FODERARO                DENISE             OPPOSE   125000.0
# 6704               DELANEY            MARY QUINN             OPPOSE   100000.0
# ...

# %%
merged.amount.sum()
# Out:
# 34291239.299999997

# %%
oppose.sort_values("amount", ascending = False).head()
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 29634  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 33752  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29635  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29633  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
# 29631  ocd-contest/19eca91d-e494-4ee0-a345-8f96eeec8a3e            1381724
#
#        ccdc_prop_id                                          prop_name  \
# 29634            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 33752            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 29635            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 29633            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
# 29631            85  PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...
#
#        ccdc_committee_id  calaccess_committee_id  \
# ...

# %%
top_supporters = support.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters.head(10)
# Out:
#       contributor_firstname contributor_lastname    amount
# 10519              HENRY T.         NICHOLAS III  400000.0
# 15205                 JULIE             MOTAMEDI  350000.0
# 26206                 SUSAN                GROFF  160000.0
# 6612             DEBRA JANE           STEINHARDT  100000.0
# 10280                 H. F.        BOECKMANN, II  100000.0
# 22733            RICHARD J.              RIORDAN  100000.0
# 4                A. JERROLD            PERENCHIO  100000.0
# 20894                PAMELA                GROFF  100000.0
# 17205                 LUCKY                LIPPA   90000.0
# 26085             STEVEN L.                CRAIG   70000.0

# %% [markdown]
# ## Experiment with matplotlib for making charts

# %%
top_supporters.amount.plot.bar()

# %%
top_supporters.amount.plot.barh()

# %%
chart = top_supporters.head(5).amount.plot.barh()

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_lastname)

# %%
top_supporters['contributor_fullname'] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters.head()
# Out:
#       contributor_firstname contributor_lastname    amount  \
# 10519              HENRY T.         NICHOLAS III  400000.0
# 15205                 JULIE             MOTAMEDI  350000.0
# 26206                 SUSAN                GROFF  160000.0
# 6612             DEBRA JANE           STEINHARDT  100000.0
# 10280                 H. F.        BOECKMANN, II  100000.0
#
#         contributor_fullname
# 10519  HENRY T. NICHOLAS III
# 15205         JULIE MOTAMEDI
# 26206            SUSAN GROFF
# 6612   DEBRA JANE STEINHARDT
# 10280    H. F. BOECKMANN, II

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_fullname)

# %%
top_supporters.head(5).to_csv("top_supporters.csv")
