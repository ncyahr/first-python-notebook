# %%
import pandas as pd

# %%
import xlrd

# %%
workbook = pd.read_excel('/Users/natalieyahr/Downloads/SearchResults_2017_6_25.xls')

# %% [raw]
# workbook.info()

# %%
workbook.ContributionAmt.value_counts().reset_index()
# Out:
#          index  ContributionAmt
# 0         5.00             5846
# 1         1.00             4644
# 2         2.00             3272
# 3         2.50             2760
# 4         3.00             2671
# 5        10.00             2013
# 6       500.00             1812
# 7       100.00             1742
# 8      1000.00             1490
# 9       250.00             1455
# 10      200.00             1278
# 11        0.50             1246
# 12        6.00             1085
# 13        4.00             1067
# 14       25.00             1000
# 15       12.00              937
# 16        7.50              852
# 17        8.00              719
# 18       50.00              715
# 19       15.00              684
# 20       20.00              592
# 21     2500.00              569
# 22     5000.00              506
# 23        0.88              480
# 24        9.00              473
# 25        0.59              436
# 26        0.70              431
# 27        1.61              425
# ...

# %%
workbook.ContributionAmt.value_counts().reset_index()
# Out:
#          index  ContributionAmt
# 0         5.00             5846
# 1         1.00             4644
# 2         2.00             3272
# 3         2.50             2760
# 4         3.00             2671
# 5        10.00             2013
# 6       500.00             1812
# 7       100.00             1742
# 8      1000.00             1490
# 9       250.00             1455
# 10      200.00             1278
# 11        0.50             1246
# 12        6.00             1085
# 13        4.00             1067
# 14       25.00             1000
# 15       12.00              937
# 16        7.50              852
# 17        8.00              719
# 18       50.00              715
# 19       15.00              684
# 20       20.00              592
# 21     2500.00              569
# 22     5000.00              506
# 23        0.88              480
# 24        9.00              473
# 25        0.59              436
# 26        0.70              431
# 27        1.61              425
# ...

# %%
workbook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
# FilerLastName              65535 non-null object
# FilerFirstName             12090 non-null object
# ReportCode                 65535 non-null object
# ReportType                 65535 non-null object
# ReportNumber               65535 non-null object
# ContributorName            65535 non-null object
# ContributorAddr1           65393 non-null object
# ContributorAddr2           3163 non-null object
# ContributorCity            65499 non-null object
# ContributorState           65498 non-null object
# ContributorZip             65477 non-null object
# ContributionType           65535 non-null object
# ContributionDescription    12783 non-null object
# ContributionDate           65535 non-null datetime64[ns]
# ContributionAmt            65535 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(13)
# memory usage: 7.5+ MB

# %%
workbook.head(50)
# Out:
#     FilerLastName FilerFirstName ReportCode ReportType ReportNumber  \
# 0   ABC Merit PAC            NaN       F202        ANN     LA-60071
# 1   ABC Merit PAC            NaN       F202        ANN     LA-60071
# 2   ABC Merit PAC            NaN       F202        ANN     LA-60732
# 3   ABC Merit PAC            NaN       F202        ANN     LA-60732
# 4   ABC Merit PAC            NaN       F202        ANN     LA-60732
# 5   ABC Merit PAC            NaN       F202        ANN     LA-60732
# 6   ABC Merit PAC            NaN       F202        ANN     LA-64415
# 7   ABC Merit PAC            NaN       F202        ANN     LA-61490
# 8   ABC Merit PAC            NaN       F202        ANN     LA-61490
# 9   ABC Merit PAC            NaN       F202        ANN     LA-61490
# 10  ABC Merit PAC            NaN       F202        ANN     LA-63815
# 11  ABC Merit PAC            NaN       F202        ANN     LA-62285
# 12  ABC Merit PAC            NaN       F202        ANN     LA-62285
# ...

# %%
workbook.ContributionAmt.max()
# Out:
# 300000.0

# %%
workbook.ContributionAmt.mean()
# Out:
# 202.36020248722056

# %%
workbook.ContributorName.value_counts().head(650).reset_index()
# Out:
#                      index  ContributorName
# 0               JAMES CASE               48
# 1               STEVEN LEE               48
# 2              DAVID BURGE               47
# 3               ALLEN EAST               42
# 4         TIMOTHY TRAMMELL               42
# 5     CAJUN INDUSTRIES LLC               39
# 6              KENT GUIDRY               34
# 7             DAVID MILLER               34
# 8         CAPITAL ONE BANK               33
# 9              DAVID ELLIS               30
# 10           WILLIAM SMITH               29
# 11          WILLIE JOHNSON               28
# 12        LAWRENCE JOHNSON               26
# 13              MARK SMITH               26
# 14           STEVEN LANDRY               26
# 15           TYLER GREGORY               25
# 16          ROBERT WHITMAN               25
# 17             NIGEL ELIAS               25
# 18      JOHANNES HAUMERSEN               25
# 19              CLAY COKER               25
# ...
